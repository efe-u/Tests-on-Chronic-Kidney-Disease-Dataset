# %%
import tensorflow as tf
import pandas as pd
import numpy as np

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.utils import shuffle
from keras.layers import * 
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.models import Sequential

# %%
def main():
  data = read_data()
  clean_data(data)
  data = handle_missing_values(data)
  axes = min_max_scaling(data)
  results = modify_dimensionality(data,axes[0],axes[1])

  # Result Printing
  indexs = ["Cross value score:","\nTrain-Test score:","\nNeural Network Accuracy score:"]

  for result in results:
    result_no = 0
    print(indexs[result_no])
    for key, value in result.items():
      print ("  ",key,":" ,value)
    result_no += 1
  print("\n\n")

# %%
def read_data():

  # convert data into dataframe
  data = pd.read_csv("kidney_disease_fixed.csv", encoding= "unicode_escape")
  data = data.drop("id", axis = 1)
  data = shuffle(data, random_state=19)
  return data

# %%
def clean_data(data):
  # Save tags and replace all empty values with "?"

  tags = []

  for col in data:
    tags.append(col)
    for value in data[col]:
      if "?" in str(value) or " " in str(value):
        data[col] = data[col].replace(to_replace = value, value = np.nan)

  # Arrange column types

  for tag in tags:
    try:
      data[tag] = pd.to_numeric(data[tag])
    except:
      pass

  # Classify column types

  non_numeric = [col for col in data if data[col].dtype == object]
  numeric = [col for col in data if data[col].dtype == float]

  # Confirm numerics

  for col in numeric:
    pd.to_numeric(data[col])

  # Conversion of non_numerics to binary
  # Cleaning before conversion

  data.dm = data.dm.replace("\tno", "no").replace(" yes", "yes").replace("\tyes", "yes")
  data.cad = data.cad.replace("\tno", "no")
  data.classification=data.classification.replace("ckd\t","ckd")

  # Conversion to binary

  data['rbc'] = data['rbc'].replace(['normal','abnormal'], [1,0])
  data['pc'] = data['pc'].replace(['normal','abnormal'], [1,0])
  data['pcc'] = data['pcc'].replace(['present','notpresent'], [1,0])
  data['ba'] = data['ba'].replace(['present','notpresent'], [1,0])
  data['htn'] = data['htn'].replace(['yes','no'], [1,0])
  data['dm'] = data['dm'].replace(['yes','no'], [1,0])
  data['cad'] = data['cad'].replace(['yes','no'], [1,0])
  data['appet'] = data['appet'].replace(['good','poor'], [1,0])
  data['pe'] = data['pe'].replace(['yes','no'], [1,0])
  data['ane'] = data['ane'].replace(['yes','no'], [1,0])
  data['classification'] = data['classification'].replace(['ckd','notckd'], [1,0])

# %%
def handle_missing_values(data):

  from sklearn.impute import KNNImputer

  imputer = KNNImputer(n_neighbors=5)
  data = pd.DataFrame(imputer.fit_transform(data),columns = data.columns)
  return(data)

# %%
def min_max_scaling(data):

  from sklearn.preprocessing import MinMaxScaler

  scaler = MinMaxScaler()
  data = scaler.fit_transform(data)

  # Assigning the dimensions of data
  X = data[:,:-1]
  Y = data[:,-1]
  return(X,Y)

# %%
def modify_dimensionality(data,X,Y):

  from sklearn.decomposition import PCA

  # Result dictionaries
  NN_results = {}
  CM_cvs_results = {}
  CM_tt_results = {}

  # Loop dimensionality

  for dimension in range(2,24):
    dimensionality = dimension

    # Reduce dimensionality

    try:
      pca = PCA(n_components=dimensionality)
      principalComponents = pca.fit_transform(X)
      X = pd.DataFrame(principalComponents, columns = ["PC1", "PC2"])
      X = X.to_numpy()
    except:
      pass

    train_test_split(data)
    apply_classification_model(X,Y,dimensionality,CM_cvs_results,CM_tt_results)
    apply_neural_network(X,Y,dimensionality,NN_results)

  # Return result dictionaries
  return(CM_cvs_results,CM_tt_results,NN_results)

# %%
def train_test_split(data):
  train_size = int(len(data) * .8)
  test_size = len(data) - train_size

  df_train = data[:train_size]
  df_test = data[train_size:]

# %%
def apply_classification_model(X,Y,dimensionality,CM_cvs_results,CM_tt_results):
  # Import
  from sklearn import svm
  from sklearn import metrics
  from sklearn.model_selection import cross_val_score
  from sklearn.model_selection import train_test_split

  # Initialize test and train
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)


  def evaluateCVS(results):
    clf = svm.SVC(kernel='linear', C=1)
    scores = cross_val_score(clf, X, Y, cv=5, scoring='accuracy')
    CM_cvs_results["D(" + str(dimensionality) + ")_accuracy"] = '%.4f' % (scores.mean()*100)
    scores = cross_val_score(clf, X, Y, cv=5, scoring='f1')
    CM_cvs_results["D(" + str(dimensionality) + ")_f1_score"] = '%.4f' % (scores.mean()*100)
    scores = cross_val_score(clf, X, Y, cv=5, scoring='recall')
    CM_cvs_results["D(" + str(dimensionality) + ")_recall_score"] = '%.4f' % (scores.mean()*100)
    
  def evaluateTT(results,model):
    CM_tt_results["D(" + str(dimensionality) + ")_" + model +"_accuracy"] = '%.4f' % (metrics.accuracy_score(Y_test, results) * 100)
    CM_tt_results["D(" + str(dimensionality) + ")_" + model +"_f1_score"] = '%.4f' % (metrics.f1_score(Y_test, results) * 100)
    CM_tt_results["D(" + str(dimensionality) + ")_" + model +"_recall_score"] = '%.4f' % (metrics.recall_score(Y_test, results) * 100)


  # Support Vector Machine

  supvm = svm.SVC(decision_function_shape='ovo')

  # Entire Data
  supvm.fit(X,Y)
  results = supvm.predict(X)

  evaluateCVS(results)

  # Train-test Data
  supvm.fit(X_train, Y_train)
  results = supvm.predict(X_test)

  evaluateTT(results, "SVM")



  # Logistic Regression

  from sklearn.linear_model import LogisticRegression

  logreg = LogisticRegression()

  # Entire Data
  logreg.fit(X, Y)
  results = logreg.predict(X)
  evaluateCVS(results)

  # Train-test Data
  logreg.fit(X_train, Y_train)
  results = logreg.predict(X_test)
  evaluateTT(results, "LogReg")



  # K-Nearest Neighbor

  from sklearn.neighbors import KNeighborsClassifier

  for neighbor in [1,5]:
    knn = KNeighborsClassifier(n_neighbors=neighbor)

    # Entire Data
    knn.fit(X, Y)
    results = knn.predict(X)

    evaluateCVS(results)

    # Train-test Data
    knn.fit(X_train, Y_train)
    results = knn.predict(X_test)

    evaluateTT(results, "KNN")



  # Decision Tree 

  from sklearn.tree import DecisionTreeClassifier

  for technique in ["gini", "entropy"]:
    clf = DecisionTreeClassifier(criterion = technique)

    # Entire Data
    clf.fit(X, Y)
    results = clf.predict(X)

    evaluateCVS(results)

    # Train-test Data
    clf.fit(X_train, Y_train)
    results = clf.predict(X_test)

    evaluateTT(results, "DecTree")



  # Random Forest Classifier

  from sklearn.ensemble import RandomForestClassifier

  rfc = RandomForestClassifier()

  # Entire Data
  rfc.fit(X, Y)
  results = rfc.predict(X)

  evaluateCVS(results)

  # Train-test Data
  rfc.fit(X_train, Y_train)
  results = rfc.predict(X_test)

  evaluateTT(results, "RandFor")

# %%
def apply_neural_network(X,Y,dimensionality,NN_results):
  # Determine model types/neuron count per layer
  neuron_types = ["Type1", "Type2", "Type3"]

  # Initialize types
  neuron_modifier = {"Type1":[24,12,1],
                    "Type2":[24,4,1],
                    "Type3":[24,3,1]}

  # Empty dictionaries for models
  model_accuracy = dict.fromkeys(["Type1", "Type2", "Type3"])
  model_history = dict.fromkeys(["Type1", "Type2", "Type3"])

  # Initialize test and train
  from sklearn.model_selection import train_test_split

  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

  # Creating the model


  def create_model(layer_size,input_shape):
    model = Sequential(name = "Sequential_Test_Model")
    model.add(Input(shape = (input_shape)))
    model.add(Dense(layer_size[1], activation = 'relu'))
    model.add(Dense(layer_size[2], activation = 'sigmoid'))
    return model

  for type_ in neuron_types:
    model = create_model(neuron_modifier[type_],X_train[0].shape)
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy']) 
    model.summary()

    # Fit model
    model_history[type_] = model.fit(X_train, Y_train, epochs=10)

    # Evaluate model
    accuracy = model.evaluate(X_test, Y_test)
    model_accuracy[type_] = accuracy[1]

    NN_results[f"d({dimensionality})"] = model_accuracy

# %%
if "__main__" == __name__:
    main()
# Out:
# Model: "Sequential_Test_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 12)                300
#
#  dense_19 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 313
# Trainable params: 313
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 4s 11ms/step - loss: 0.2625 - accuracy: 0.4844
# Epoch 2/10
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2236 - accuracy: 0.5875
# Epoch 3/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1922 - accuracy: 0.7188
# Epoch 4/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1690 - accuracy: 0.8219
# Epoch 5/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1571 - accuracy: 0.8844
# Epoch 6/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1466 - accuracy: 0.9281
# Epoch 7/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1383 - accuracy: 0.9375
# Epoch 8/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1288 - accuracy: 0.9344
# Epoch 9/10
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1181 - accuracy: 0.9281
# Epoch 10/10
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1069 - accuracy: 0.9250
# 3/3 [==============================] - 1s 6ms/step - loss: 0.1124 - accuracy: 0.9625
# Model: "Sequential_Test_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 4)                 100
#
#  dense_21 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 105
# Trainable params: 105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 2s 3ms/step - loss: 0.2486 - accuracy: 0.4625
# Epoch 2/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2364 - accuracy: 0.4781
# Epoch 3/10
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2245 - accuracy: 0.5469
# Epoch 4/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2126 - accuracy: 0.5969
# Epoch 5/10
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2002 - accuracy: 0.7031
# Epoch 6/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1874 - accuracy: 0.7750
# Epoch 7/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1741 - accuracy: 0.8469
# Epoch 8/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1633 - accuracy: 0.8625
# Epoch 9/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1553 - accuracy: 0.8719
# Epoch 10/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1482 - accuracy: 0.8875
# 3/3 [==============================] - 1s 6ms/step - loss: 0.1359 - accuracy: 0.9000
# Model: "Sequential_Test_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 3)                 75
#
#  dense_23 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 79
# Trainable params: 79
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 2s 4ms/step - loss: 0.2704 - accuracy: 0.5281
# Epoch 2/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.2657 - accuracy: 0.5531
# Epoch 3/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.5688
# Epoch 4/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.5875
# Epoch 5/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2533 - accuracy: 0.5906
# Epoch 6/10
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2499 - accuracy: 0.6094
# Epoch 7/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2470 - accuracy: 0.6094
# Epoch 8/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2444 - accuracy: 0.6187
# Epoch 9/10
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2416 - accuracy: 0.6250
# Epoch 10/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2386 - accuracy: 0.6250
# 3/3 [==============================] - 1s 4ms/step - loss: 0.2383 - accuracy: 0.6250
# Model: "Sequential_Test_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 12)                300
#
#  dense_25 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 313
# Trainable params: 313
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 2s 3ms/step - loss: 0.2960 - accuracy: 0.3750
# Epoch 2/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2734 - accuracy: 0.3938
# Epoch 3/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2535 - accuracy: 0.4688
# Epoch 4/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.5594
# Epoch 5/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2273 - accuracy: 0.6562
# Epoch 6/10
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2161 - accuracy: 0.7500
# Epoch 7/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2056 - accuracy: 0.8219
# Epoch 8/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1951 - accuracy: 0.8469
# Epoch 9/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1850 - accuracy: 0.8656
# Epoch 10/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1748 - accuracy: 0.8813
# 3/3 [==============================] - 1s 4ms/step - loss: 0.1773 - accuracy: 0.8375
# Model: "Sequential_Test_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_26 (Dense)            (None, 4)                 100
#
#  dense_27 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 105
# Trainable params: 105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 2s 3ms/step - loss: 0.2075 - accuracy: 0.6250
# Epoch 2/10
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1969 - accuracy: 0.6281
# Epoch 3/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1892 - accuracy: 0.6344
# Epoch 4/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1839 - accuracy: 0.6281
# Epoch 5/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 0.6250
# Epoch 6/10
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1736 - accuracy: 0.6438
# Epoch 7/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1691 - accuracy: 0.6750
# Epoch 8/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1654 - accuracy: 0.6938
# Epoch 9/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 0.7094
# Epoch 10/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1585 - accuracy: 0.7375
# 3/3 [==============================] - 1s 6ms/step - loss: 0.1664 - accuracy: 0.7500
# Model: "Sequential_Test_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 3)                 75
#
#  dense_29 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 79
# Trainable params: 79
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 2s 5ms/step - loss: 0.2417 - accuracy: 0.6250
# Epoch 2/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2377 - accuracy: 0.6187
# Epoch 3/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2334 - accuracy: 0.6187
# Epoch 4/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2296 - accuracy: 0.6219
# Epoch 5/10
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2264 - accuracy: 0.6250
# Epoch 6/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2227 - accuracy: 0.6250
# Epoch 7/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2191 - accuracy: 0.6250
# Epoch 8/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2152 - accuracy: 0.6250
# Epoch 9/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2112 - accuracy: 0.6250
# Epoch 10/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2076 - accuracy: 0.6250
# 3/3 [==============================] - 1s 7ms/step - loss: 0.2122 - accuracy: 0.6250
# Model: "Sequential_Test_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 12)                300
#
#  dense_31 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 313
# Trainable params: 313
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 2s 2ms/step - loss: 0.2634 - accuracy: 0.5312
# Epoch 2/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2424 - accuracy: 0.6250
# Epoch 3/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.2245 - accuracy: 0.7594
# Epoch 4/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2087 - accuracy: 0.8219
# Epoch 5/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1940 - accuracy: 0.8625
# Epoch 6/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1802 - accuracy: 0.8844
# Epoch 7/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1670 - accuracy: 0.9000
# Epoch 8/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1546 - accuracy: 0.8969
# Epoch 9/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1430 - accuracy: 0.8969
# Epoch 10/10
# 10/10 [==============================] - 0s 16ms/step - loss: 0.1324 - accuracy: 0.9094
# 3/3 [==============================] - 1s 7ms/step - loss: 0.1504 - accuracy: 0.8625
# Model: "Sequential_Test_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 4)                 100
#
#  dense_33 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 105
# Trainable params: 105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 2s 3ms/step - loss: 0.2632 - accuracy: 0.6250
# Epoch 2/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2435 - accuracy: 0.6219
# Epoch 3/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2210 - accuracy: 0.6187
# Epoch 4/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2015 - accuracy: 0.6156
# Epoch 5/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1835 - accuracy: 0.6031
# Epoch 6/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1695 - accuracy: 0.6219
# Epoch 7/10
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1590 - accuracy: 0.7719
# Epoch 8/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 0.9125
# Epoch 9/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1443 - accuracy: 0.9344
# Epoch 10/10
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1385 - accuracy: 0.9250
# 3/3 [==============================] - 1s 3ms/step - loss: 0.1446 - accuracy: 0.8750
# Model: "Sequential_Test_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_34 (Dense)            (None, 3)                 75
#
#  dense_35 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 79
# Trainable params: 79
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 2s 3ms/step - loss: 0.2533 - accuracy: 0.6156
# Epoch 2/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2482 - accuracy: 0.6250
# Epoch 3/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2430 - accuracy: 0.6250
# Epoch 4/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.6250
# Epoch 5/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2336 - accuracy: 0.6250
# Epoch 6/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2300 - accuracy: 0.6250
# Epoch 7/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2270 - accuracy: 0.6250
# Epoch 8/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2239 - accuracy: 0.6250
# Epoch 9/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2207 - accuracy: 0.6250
# Epoch 10/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2174 - accuracy: 0.6250
# 3/3 [==============================] - 1s 4ms/step - loss: 0.2171 - accuracy: 0.6250
# Cross value score:
#    D(23)_accuracy : 98.2500
#    D(23)_f1_score : 98.5936
#    D(23)_recall_score : 98.4000
#    D(15)_accuracy : 98.2500
#    D(15)_f1_score : 98.5936
#    D(15)_recall_score : 98.4000
#    D(6)_accuracy : 98.2500
#    D(6)_f1_score : 98.5936
#    D(6)_recall_score : 98.4000
# Cross value score:
#    D(23)_SVM_accuracy : 100.0000
#    D(23)_SVM_f1_score : 100.0000
#    D(23)_SVM_recall_score : 100.0000
#    D(23)_LogReg_accuracy : 97.5000
#    D(23)_LogReg_f1_score : 97.9592
#    D(23)_LogReg_recall_score : 96.0000
#    D(23)_KNN_accuracy : 96.2500
#    D(23)_KNN_f1_score : 96.9072
#    D(23)_KNN_recall_score : 94.0000
#    D(23)_DecTree_accuracy : 95.0000
#    D(23)_DecTree_f1_score : 95.9184
#    D(23)_DecTree_recall_score : 94.0000
#    D(23)_RandFor_accuracy : 98.7500
#    D(23)_RandFor_f1_score : 99.0099
#    D(23)_RandFor_recall_score : 100.0000
#    D(15)_SVM_accuracy : 100.0000
#    D(15)_SVM_f1_score : 100.0000
#    D(15)_SVM_recall_score : 100.0000
#    D(15)_LogReg_accuracy : 97.5000
#    D(15)_LogReg_f1_score : 97.9592
#    D(15)_LogReg_recall_score : 96.0000
#    D(15)_KNN_accuracy : 96.2500
#    D(15)_KNN_f1_score : 96.9072
#    D(15)_KNN_recall_score : 94.0000
#    D(15)_DecTree_accuracy : 92.5000
#    D(15)_DecTree_f1_score : 93.8776
#    D(15)_DecTree_recall_score : 92.0000
#    D(15)_RandFor_accuracy : 97.5000
#    D(15)_RandFor_f1_score : 98.0000
#    D(15)_RandFor_recall_score : 98.0000
#    D(6)_SVM_accuracy : 100.0000
#    D(6)_SVM_f1_score : 100.0000
#    D(6)_SVM_recall_score : 100.0000
#    D(6)_LogReg_accuracy : 97.5000
#    D(6)_LogReg_f1_score : 97.9592
#    D(6)_LogReg_recall_score : 96.0000
#    D(6)_KNN_accuracy : 96.2500
#    D(6)_KNN_f1_score : 96.9072
#    D(6)_KNN_recall_score : 94.0000
#    D(6)_DecTree_accuracy : 95.0000
#    D(6)_DecTree_f1_score : 95.9184
#    D(6)_DecTree_recall_score : 94.0000
#    D(6)_RandFor_accuracy : 98.7500
#    D(6)_RandFor_f1_score : 99.0099
#    D(6)_RandFor_recall_score : 100.0000
# Cross value score:
#    d(23) : {'Type1': 0.9624999761581421, 'Type2': 0.8999999761581421, 'Type3': 0.625}
#    d(15) : {'Type1': 0.8374999761581421, 'Type2': 0.75, 'Type3': 0.625}
#    d(6) : {'Type1': 0.862500011920929, 'Type2': 0.875, 'Type3': 0.625}
